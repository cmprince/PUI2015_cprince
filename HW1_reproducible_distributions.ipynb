# %% [markdown]
# # I want you to create a <i>reproducible research</i> code
# that means we want the reader to be able to reproduce every step of our analysis. when stochastic processes and random variables are involved that gets tricky, but since computers are unable to rpoduce truly random numbers, we can actually reproduce every series of "pseudo random" number generated by a computer as long as we know what seed is used. <i>The first seed will determin entirely the distribution that is generated, and the seeds of the following distriburions generated by the code!</i>

# %%
import os
import sys
import numpy as np

# %% [markdown]
# #THIS IS THE MOST IMPORTANT PIECE OF THIS CODE!
# ##we must give numpy as seed for this code to be reproducible
# http://docs.scipy.org/doc/numpy/reference/generated/numpy.random.seed.html

# %%
np.random.seed(11215)

# %% [markdown]
# ##use this function to generate 100 2-dimensional random datapoints in a gaussian distribution in 2 dimensions
#
# http://docs.scipy.org/doc/numpy/reference/generated/numpy.random.randn.html

# %%
np.random.randn(100,2)
# Out:
# array([[-1.39930529, -0.24483859],
#        [ 0.3217982 ,  0.67857532],
#        [ 0.77429237, -0.91305456],
#        [-1.43220512,  1.76399419],
#        [ 0.61102369, -0.37578031],
#        [-1.18341766, -2.51970442],
#        [-0.91229265, -0.63116947],
#        [ 0.67243481, -1.73102771],
#        [ 0.08249858, -0.31096673],
#        [-0.32151068, -1.37603235],
#        [ 0.24207979, -0.3416014 ],
#        [ 0.25512149, -0.22074061],
#        [ 0.13118093, -0.87101734],
#        [-2.570547  , -0.4786981 ],
#        [-0.18144552, -2.12337258],
#        [-0.28889671,  0.76063801],
#        [ 1.81669324, -2.18512369],
#        [-0.13635368, -0.36928715],
#        [ 0.85408454, -1.49406715],
#        [-0.73821604,  0.75554956],
#        [-1.87010713, -2.04940754],
#        [-0.87020112,  1.00831515],
#        [ 0.9772466 , -2.09917935],
#        [ 1.35040121,  0.24034097],
#        [-1.0474154 , -1.25653314],
#        [-0.39739149,  0.55377324],
#        [-0.11714828,  1.49317198],
#        [-0.64375616,  2.47526375],
#        [-0.43471496,  0.98083685],
#        [-0.23834141,  1.24660699],
#        [ 0.06772029, -0.01912992],
#        [-0.70747108, -1.23614953],
#        [-0.75188132,  0.31855998],
#        [ 0.28690913, -0.54164896],
#        [ 1.15920999,  1.34400357],
#        [ 2.12988479, -1.40903838],
#        [ 0.49850228,  0.33019501],
#        [ 0.74042422,  0.46903736],
#        [ 1.34950176, -0.21891261],
#        [-1.52796585,  0.92996992],
#        [-0.1588457 ,  0.4863474 ],
#        [ 0.61836067,  0.29203305],
#        [ 0.45548733,  0.19543332],
#        [-0.11182444,  1.42239748],
#        [ 0.11785646, -0.67863357],
#        [-0.13107429,  0.38865512],
#        [-0.59762724, -0.20211673],
#        [ 2.06761593, -0.54519934],
#        [ 0.44377518, -0.62444428],
#        [ 1.20381983,  0.69198413],
#        [ 0.44426069, -0.54740472],
#        [-1.07342757,  0.20740228],
#        [-0.02968355, -0.3105467 ],
#        [-1.43240179, -0.30604939],
#        [ 0.7307203 , -0.23969148],
#        [ 0.61294179,  1.44496361],
#        [-0.75094947, -1.01257084],
#        [ 0.09063074, -1.87791939],
#        [ 0.41032427,  0.12896362],
#        [-0.21488245,  0.25389242],
#        [-0.18717605, -1.09340814],
#        [ 1.02311967,  1.42501857],
#        [ 0.24257324, -1.30723709],
#        [-0.75920313,  0.47129643],
#        [-0.89215409,  1.39321926],
#        [-0.48936495,  1.04553204],
#        [ 0.8057002 , -0.49428151],
#        [ 0.2870298 , -1.51396618],
#        [-0.11241534,  0.69605874],
#        [ 0.97994007, -0.44533859],
#        [ 0.22377383, -1.66925571],
#        [-1.10839299,  0.01626752],
#        [ 0.69368252, -0.8622446 ],
#        [ 0.46461456,  0.00632522],
#        [-0.26593378,  0.43593145],
#        [ 1.58203352,  0.45635988],
#        [-0.74879904,  1.95536698],
#        [ 0.5906407 ,  0.55848298],
#        [ 0.42062878,  0.14561749],
#        [-0.46771794, -0.10577787],
#        [ 0.71254289, -0.64758914],
#        [-0.13033309, -0.61070234],
#        [ 0.27320037,  0.1926428 ],
#        [-1.0946507 , -1.16303806],
#        [-0.31328396, -0.57885986],
#        [-0.43095147,  0.5827804 ],
#        [-1.60142989, -0.27933308],
#        [ 0.34859212,  0.15014044],
#        [-2.94860222, -0.11453262],
#        [-1.42374998,  1.17839069],
#        [ 0.93800051, -0.33692347],
#        [ 1.48635312, -1.4314143 ],
#        [ 0.87857604, -0.903995  ],
#        [ 0.3001475 , -0.87708336],
#        [-0.3960723 , -0.35196595],
#        [-0.17739786, -1.82998715],
#        [-1.27504305, -0.05222351],
#        [-2.25818548,  1.74233089],
#        [ 1.02874715,  0.26951576],
#        [-0.46808023,  0.53196995]])

# %% [markdown]
# ## use the same function to generate 50 more random objects, but this time change the mean
# to do that you multiply the distribution by a different sigma, and add your new mean - remember that these are 2D objects, so yor mean must be a 2D vector (a list, an array or a tuple)!

# %%
N2d = 42*np.random.randn(100,2)+[220,115]

# %% [markdown]
# ##now plot them with this function:
#
# https://scipy-lectures.github.io/intro/matplotlib/matplotlib.html#scatter-plots
#
# ##if you print the array it will be a 2x100: 100 2D objects. although that is what we wanted we cannot plot it easily this way: there are many ways to deal with it. the goal is to pass the first dimension as the disrt argument to scatter, and the second dimension as the second argument. i am gonna do it by transposing the array (switching the axes)

# %%
import pylab as pl
# %matplotlib inline

# %%
pl.scatter(N2d[:,0],N2d[:,1])
pl.show()

# %% [markdown]
# ##first plot them as a single distribution, then change the color for the 2 samples
#
# remember to give your labels some names and to make a legend! in the legend tell me what the mean and standard deviation of each sample is
